# %%
import matplotlib.pyplot as plt

# %%
x = [1000,10000,100000,1000000,10000000,100000000]

py_loop = [0.000591,0.004957,0.0433143,0.41504867,3.984729333,40.20658733]
pypy_loop = [0.001126,0.004965,0.0229547,0.21753667,2.105114333,20.67685]
numba_loop = [0.217537,0.219734,0.234032,0.378058,1.857648333,16.260301]
c = [0.002,0.004,0.022,0.15633333,1.46333333,14.488]

x_rk = [1000,10000,100000,1000000]
py_rk = [0.041933,0.421702,4.185119,41.5107653]
pypy_rk = [0.309227,2.543413,23.769834,238.752122]
numba_rk = [0.971745,0.976078,1.0340913,1.62095967]

solve_ivp = [0.005115,0.005653,0.0106697,0.062696]

# %%
plt1 = plt.plot(x,py_loop,'r-',x,pypy_loop,'b-')
plt.title('python(red) / pypy(blue) - Savage')
plt.xlabel('Problem Size')
plt.ylabel('time (s)')
plt.show()

# %%
plt2 = plt.plot(x,py_loop,'r-',x,pypy_loop,'b-',x,numba_loop,'g-')
plt.title('python(red) / pypy(blue) / numba(green) - Savage')
plt.xlabel('Problem Size')
plt.ylabel('time (s)')
plt.show()

# %%
plt3 = plt.plot(x_rk,py_rk,'r-',x_rk,pypy_rk,'b-')
plt.title('python(red) / pypy(blue) - RK')
plt.xlabel('Problem Size')
plt.ylabel('time (s)')
plt.show()

# %%
plt4 = plt.plot(x_rk,py_rk,'r-',x_rk,pypy_rk,'b-',x_rk,numba_rk,'g-')
plt.title('python(red) / pypy(blue) / numba(green) - RK')
plt.xlabel('Problem Size')
plt.ylabel('time (s)')
plt.show()

# %%
plt5 = plt.plot(x_rk,py_rk,'r-',x_rk,numba_rk,'g-',x_rk,solve_ivp,'y-')
plt.title('python(red) / numba(green) / scipy(yellow) - RK')
plt.xlabel('Problem Size')
plt.ylabel('time (s)')
plt.show()
